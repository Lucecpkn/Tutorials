# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucecpkn/Tutorials/blob/master/WebDataExtraction_Pan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introduction to BeatifulSoup

# %% [markdown]
# Beautiful Soup is a popular Python library for pulling data out of HTML files. Today we will learn to use some of its basic functions.
# To know more, you can refer to its [documentation](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#).

# %% [markdown]
# ### Python notebook

# %%
print("hello world")   ## this is a code block
# Out:
# hello world

# %% [markdown]
# ### Example: get HEC faculty list
# We want to get the data of all faculty names of HEC.

# %% [markdown]
# Packages we will use:

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# #### 1. Get the HTML of the webpage.

# %% [markdown]
# Get the html source file of the [webpage](https://www.hec.ca/en/profs/profs.html):

# %%
url = 'https://www.hec.ca/en/profs/profs.html'
source = requests.get(url).text  # source is a html
soup = BeautifulSoup(source)  # soup is a tree
print(soup.prettify())

# %% [markdown]
# #### 2. Locate the target information:

# %% [markdown]
# The html in the text format seems messy. It's hard to locate information in it.
# Luckily we don't have to, thanks to the browsers.

# %% [markdown]
# To view the source code of a page, use the `Developer Tools` of the browser.

# %% [markdown]
# Ex.
# For **Chrome**:  `Setting --> More tools --> Developer Tools`.
# ![image.png ](data:image/png;base64,...)

# %% [markdown]
# For **Safari**, you first need to enable the Developer menu:
# - Click on Safari menu > Preferences > Advanced.
# - Check "Show Develop menu in menu bar".
# - Close the Preferences window.
# - Go to the Develop menu > Show Page Source

# %% [markdown]
# Now you should be able to locate elements which contain the target information.

# %% [markdown]
# Here in our example, we find that the info we need is in the elements of type \<a class="hTypeMenu"> within the element \<div class_='ALBOfProfs'>.

# %% [markdown]
# #### 3. Extract the information

# %% [markdown]
# First, we narrow down to the table element containing all info, using the function `find()`:

# %%
table = soup.find('div', class_='ALBOfProfs')

# %% [markdown]
# Then, we extract all the rows using the function `find_all()`:

# %%
## each row contains info of a prof
rows = table.find_all("div", class_="row")

# %% [markdown]
# The names are found in the first \<a class="hTypeMenu"> element of each row:
#
# `element.text` will return the content of each element:

# %%
for row in rows:
  name = row.find("a", class_="hTypeMenu").text
  print(name)
# Out:
# Aboul-Enein, Shady
# Abraham, Yves-Marie
# Adulyasak, Yossiri
# AgoguÃ©, Marine
# Aguilar Delgado, Natalia
# Ahmadsimab, Alireza
# Aktouf, Omar
# Albert, Marie-Christine
# Allain, Ãlodie
# Allard, Marie-HÃ©lÃ¨ne
# Ananou, Claude
# Arcand, SÃ©bastien
# Ardia, David
# Arslan, Okan
# AubÃ©, Caroline
# Audette, Sylvain M.
# Avis, Eric
# Babin, Gilbert
# Bahn, Olivier
# Balloffet, Pierre
# Bareil, CÃ©line
# BarÃ¨s, Franck
# Baribeault, Charles
# Barin Cruz, Luciano
# Barnea, Amir
# Beaudoin, Claude
# BÃ©langer, Carol
# BÃ©langer, ValÃ©rie
# BÃ©langer-Martin, Luc
# Bellavance, FranÃ§ois
# Belzile, Germain
# Belzile, LÃ©o
# Ben Ameur, Hatem
# Betschinger, Marie-Ann
# Blain, Richard
# Boisvert, Nathalie
# Bouakez, Hafedh
# Bouchard, Philippe
# Bougie, Jacques
# Bourgoin, Alaric
# Bourhis, Anne
# Boyer, Martin
# Bozec, Yves
# Brat, Ãric
# Breton, MichÃ¨le
# BriÃ¨re, Yannick
# Brouillette, Marie-Claude
# Brunelle, Eric
# Brunet, Fabrice
# Brunet, Johanne
# Brunet, Maude
# Cacciatore, Matteo
# Cameron, Ann-Frances
# Candian, Giacomo
# Caporossi, Gilles
# Caron, Justin
# Cauchon, Denis
# Cenesizoglu, Tolga
# Chagnon, AndrÃ©
# Chanlat, Jean-FranÃ§ois
# Charlin, Laurent
# Charpin, Remi
# Chauny, Fabien
# ChÃªnevert, Denis
# Cherif, Rim
# Cisneros Martinez, Luis Felipe
# Cloutier, Charlotte
# Cloutier, Michel
# Codello, PÃ©nÃ©lope
# Cohendet, Patrick
# Coiquaud, Urwana
# Colbert, FranÃ§ois
# Comeau, Kathleen
# Cordeau, Jean-FranÃ§ois
# Cossette, Michel
# Courchesne, AndrÃ©
# Coursaris, Constantinos
# Courville, LÃ©on
# Cousineau, Martin
# Coviello, Decio
# Cziffra, Johnathon
# d'Astous, Alain
# d'Astous, Philippe
# Dantas, Danilo
# Daoust, Laurence
# Davidson, Martine
# Delage, Erick
# Denault, Michel
# Dermarkar, Simon
# DeschÃªnes, Jonathan
# Deshayes, Karine
# Despatie-Gagnon, AndrÃ©e-Anne
# Desrosiers, Jacques
# Devin, Yves
# Dionne, Georges
# Dissou, Zoffirath
# Di Vito, Jackie
# Doloreux, David
# Dorion, Christian
# Dostie, Benoit
# Doucet, Olivier
# DubÃ©, Line
# DubÃ©, Patrick
# Dulipovici, Alina Maria
# Dupuis, Debbie J.
# Dupuis, Jean-Pierre
# Durand, AurÃ©lia
# Edwards, Gwyneth
# Elgrably, Nathalie
# Elkaim, Alain
# Elshafei, Shereef
# Ethier, StÃ©phane
# Fabien, Louis
# Facal, Joseph
# Fournier, Mathieu
# Fralich, Russell
# Francoeur, Claude
# FranÃ§ois, Pascal
# Fredette, Marc
# Frenette, Johane
# GagnÃ©, Robert
# Gaudet, Marie-Claude
# Gauthier, Bernard
# Gauthier, GeneviÃ¨ve
# Gebhardt, Gary
# Geha, Jean-Luc
# Gendreau, RenÃ©
# Genest, Nadia
# Ghadiri, Djahanchah Philip (Sacha)
# Giroux, Francine
# Gomez GutiÃ©rrez, Luania
# Gowrisankaran, Gautam
# Grandmont, GÃ©rald
# Grange, Camille
# Grass, Gunnar
# GrÃ©goire, Denis
# GrÃ©goire, Vincent
# GrÃ©goire, Yany
# Gruber, Verena
# GuÃ©rard, Annie
# Hafsi, TaÃ¯eb
# Hahn, Till-Arne
# Hansen, Pierre
# Harvey, Jean-FranÃ§ois
# Haurie, Alain
# Hazgui, Mouna
# HÃ©bert, Louis
# Hennebert, Marc-Antonin
# Hernandez, Miguel
# Heumann, Tibor
# Hill, Kevin
# Jabali, Ola
# Jacques, RÃ©al
# Jans, Raf
# Jeanneret, Alexandre
# Jobin, Marie-HÃ©lÃ¨ne
# Johnson, Kevin J.
# Joly, Allain
# Kacher, Fatiha
# Khoury, Rabih
# King, Brian
# Knani, Mouna
# Labbe, AurÃ©lie
# LabbÃ©, Chantal
# Labrecque, JoAnne
# Lachance, Renaud
# Lafortune, AndrÃ©e
# Lafrance, Serge
# Lafrance, Sylvain
# Lainey, Pierre
# Lalancette, Simon
# Lambert, Caroline
# Landry, Suzanne
# Landry, Sylvain
# Langley, Ann
# Laporte, Gilbert
# Laporte, Sandra
# Tessier, Sophie
# Tezer, Ali
# Thai, Mai Thi Thanh
# Titah, Ryad
# Tomiuk, Marc Alexandre
# Traum, Nora
# Tremblay, Michel
# Trudel, Marie-Claude
# TunÃ§el, Tuba
# Turbide, Johanne
# Turgeon, Normand
# Turkina, Ekaterina
# Vaillancourt, Jean
# Valery, Pascale
# VallÃ©e, Mireille
# Van Assche, Ari
# Vandenberghe, Christian
# van Norden, Simon
# VÃ©zina, Martine
# VÃ©zina, Michel
# Vial, Gregory
# Vidal, Jean-Pierre
# Vincent, Nicolas
# Warin, Thierry
# Zaccour, Georges
# Zrill, Lanny

# %% [markdown]
# That's it, we get all the names of professors!

# %% [markdown]
# #### 4. Output data

# %% [markdown]
# Additionally, you can export the data.

# %%
names = []  ## initiate an empty list to store the names.
for row in rows:
  name = row.find("a", class_="hTypeMenu").text
  names.append(name)  ## add each name to the list

# %%
import pandas as pd
df_names = pd.DataFrame(names)

# %%
print(df_names)
# Out:
#                             0
# 0          Aboul-Enein, Shady
# 1         Abraham, Yves-Marie
# 2          Adulyasak, Yossiri
# 3             AgoguÃ©, Marine
# 4    Aguilar Delgado, Natalia
# 5         Ahmadsimab, Alireza
# 6                Aktouf, Omar
# 7     Albert, Marie-Christine
# 8             Allain, Ãlodie
# 9      Allard, Marie-HÃ©lÃ¨ne
# 10             Ananou, Claude
# 11         Arcand, SÃ©bastien
# 12               Ardia, David
# 13               Arslan, Okan
# 14            AubÃ©, Caroline
# 15        Audette, Sylvain M.
# 16                 Avis, Eric
# 17             Babin, Gilbert
# 18              Bahn, Olivier
# 19          Balloffet, Pierre
# 20            Bareil, CÃ©line
# 21            BarÃ¨s, Franck
# 22        Baribeault, Charles
# 23        Barin Cruz, Luciano
# 24              Barnea, Amir
# 25           Beaudoin, Claude
# 26           BÃ©langer, Carol
# 27        BÃ©langer, ValÃ©rie
# 28      BÃ©langer-Martin, Luc
# 29      Bellavance, FranÃ§ois
# ..                        ...
# 296             Tams , Stefan
# 297                Tang, Jian
# 298      Tarte, Jean-Philippe
# 299        TchokoguÃ©, AndrÃ©
# 300           Tessier, Sophie
# 301                Tezer, Ali
# 302       Thai, Mai Thi Thanh
# 303               Titah, Ryad
# 304    Tomiuk, Marc Alexandre
# 305               Traum, Nora
# 306          Tremblay, Michel
# 307      Trudel, Marie-Claude
# 308             TunÃ§el, Tuba
# 309          Turbide, Johanne
# 310          Turgeon, Normand
# 311        Turkina, Ekaterina
# 312        Vaillancourt, Jean
# 313           Valery, Pascale
# 314         VallÃ©e, Mireille
# 315           Van Assche, Ari
# 316   Vandenberghe, Christian
# 317         van Norden, Simon
# 318          VÃ©zina, Martine
# 319           VÃ©zina, Michel
# 320             Vial, Gregory
# 321        Vidal, Jean-Pierre
# 322          Vincent, Nicolas
# 323            Warin, Thierry
# 324          Zaccour, Georges
# 325              Zrill, Lanny
#
# [326 rows x 1 columns]

# %%
from google.colab import files
df_names.to_csv('df_names.csv')
files.download('df_names.csv')3333333

# %% [markdown]
# ## Some useful resource for learning

# %% [markdown]
# Inro to HTML: https://www.codecademy.com/learn/learn-html/modules/learn-html-elements .
# BeautifulSoup documents: https://www.crummy.com/software/BeautifulSoup/bs4/doc/# .
